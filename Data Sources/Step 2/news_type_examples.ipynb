# %%
import pandas as pd

data = pd.read_csv('filtered_fake_dataset.csv')

grouped = data.groupby('type')

# Getting 3 rows for each news type
result = grouped.head(3)

pd.set_option('display.max_colwidth', None)
display(result)
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 33       33
# 34       34
# 35       35
# 57       57
# 58       58
# 59       59
# 60       60
# 61       61
# 379     379
# 1524   1524
# 1525   1525
# 1526   1526
# 2329   2329
# 2330   2330
# 2331   2331
# 2475   2475
# 2476   2476
# 6422   6422
#
#                                                                                                                                 title  \
# 0                                                                               Muslims BUSTED: They Stole Millions In Gov’t Benefits
# 1                                                                         Re: Why Did Attorney General Loretta Lynch Plead The Fifth?
# 2                                                                BREAKING: Weiner Cooperating With FBI On Hillary Email Investigation
# 33                                    ‘Intl Community Still Financing, Protecting Terrorists’ – Mother Agnes, Vanessa Beeley on Syria
# ...
